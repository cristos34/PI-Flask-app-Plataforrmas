# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns

# %%
import glob

# %%
amazon_prime_titles=pd.read_csv(r"C:\Users\CAC\Desktop\HENRY\DATA SCIENSE\1 CURSO DT08-GRUPO 03\PROYECTOS FINALES\PI DATA ENGINEER 13-03-2023\FastApiPlataforma\PI -punto PY\amazon_prime_titles.csv",sep=",")
disney_plus_titles=pd.read_csv(r"C:\Users\CAC\Desktop\HENRY\DATA SCIENSE\1 CURSO DT08-GRUPO 03\PROYECTOS FINALES\PI DATA ENGINEER 13-03-2023\FastApiPlataforma\PI -punto PY\disney_plus_titles.csv",sep=",")
hulu_titles=pd.read_csv(r"C:\Users\CAC\Desktop\HENRY\DATA SCIENSE\1 CURSO DT08-GRUPO 03\PROYECTOS FINALES\PI DATA ENGINEER 13-03-2023\FastApiPlataforma\PI -punto PY\hulu_titles.csv",sep=",")
netflix_titles=pd.read_csv(r"C:\Users\CAC\Desktop\HENRY\DATA SCIENSE\1 CURSO DT08-GRUPO 03\PROYECTOS FINALES\PI DATA ENGINEER 13-03-2023\FastApiPlataforma\PI -punto PY\netflix_titles.csv",sep=",")
glob.glob(r"C:\Users\CAC\Desktop\HENRY\DATA SCIENSE\1 CURSO DT08-GRUPO 03\PROYECTOS FINALES\PI DATA ENGINEER 13-03-2023\PI_ML_OPS-main\Dataset\MLOpsReviews\ratings\*.csv")
# Out:
# ['C:\\Users\\CAC\\Desktop\\HENRY\\DATA SCIENSE\\1 CURSO DT08-GRUPO 03\\PROYECTOS FINALES\\PI DATA ENGINEER 13-03-2023\\PI_ML_OPS-main\\Dataset\\MLOpsReviews\\ratings\\1.csv',
#  'C:\\Users\\CAC\\Desktop\\HENRY\\DATA SCIENSE\\1 CURSO DT08-GRUPO 03\\PROYECTOS FINALES\\PI DATA ENGINEER 13-03-2023\\PI_ML_OPS-main\\Dataset\\MLOpsReviews\\ratings\\2.csv',
#  'C:\\Users\\CAC\\Desktop\\HENRY\\DATA SCIENSE\\1 CURSO DT08-GRUPO 03\\PROYECTOS FINALES\\PI DATA ENGINEER 13-03-2023\\PI_ML_OPS-main\\Dataset\\MLOpsReviews\\ratings\\3.csv',
#  'C:\\Users\\CAC\\Desktop\\HENRY\\DATA SCIENSE\\1 CURSO DT08-GRUPO 03\\PROYECTOS FINALES\\PI DATA ENGINEER 13-03-2023\\PI_ML_OPS-main\\Dataset\\MLOpsReviews\\ratings\\4.csv',
#  'C:\\Users\\CAC\\Desktop\\HENRY\\DATA SCIENSE\\1 CURSO DT08-GRUPO 03\\PROYECTOS FINALES\\PI DATA ENGINEER 13-03-2023\\PI_ML_OPS-main\\Dataset\\MLOpsReviews\\ratings\\5.csv',
# ...

# %%
amazon_prime_title=amazon_prime_titles.copy()
disney_plus_title=disney_plus_titles.copy()
hulu_title=hulu_titles .copy() 
netflix_title=netflix_titles.copy()

# %%
amazon_prime_title["show_id"]="a"+amazon_prime_title["show_id"]
disney_plus_title["show_id"]="d"+disney_plus_title["show_id"]
hulu_title["show_id"]="h"+hulu_title["show_id"]
netflix_title["show_id"]="n"+netflix_title["show_id"]

#se crea una columna con el nombre de las plataformas
amazon_prime_title["plataforma"]="amazon"
disney_plus_title["plataforma"]="disney"
hulu_title["plataforma"]="hulu"
netflix_title["plataforma"]="netflix"

# %%
General = amazon_prime_title.append(disney_plus_title).append(hulu_title).append(netflix_title)
b=General.copy()
b.rename(columns={ 'show_id' : 'id' },inplace=True)
b
# Out:
# C:\Users\CAC\AppData\Local\Temp\ipykernel_11196\810477612.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   General = amazon_prime_title.append(disney_plus_title).append(hulu_title).append(netflix_title)
# C:\Users\CAC\AppData\Local\Temp\ipykernel_11196\810477612.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   General = amazon_prime_title.append(disney_plus_title).append(hulu_title).append(netflix_title)
#           id     type                 title         director  \
# 0        as1    Movie   The Grand Seduction     Don McKellar
# 1        as2    Movie  Take Care Good Night     Girish Joshi
# 2        as3    Movie  Secrets of Deception      Josh Webber
# 3        as4    Movie    Pink: Staying True   Sonia Anderson
# 4        as5    Movie         Monster Maker     Giles Foster
# ...

# %%
dfRatings=pd.concat(map(pd.read_csv,glob.glob(r"C:\Users\CAC\Desktop\HENRY\DATA SCIENSE\1 CURSO DT08-GRUPO 03\PROYECTOS FINALES\PI DATA ENGINEER 13-03-2023\PI_ML_OPS-main\Dataset\MLOpsReviews\ratings\*.csv")))
dfRatings.rename(columns={ 'movieId' : 'id' },inplace=True)
dfRatings
# Out:
#          userId  rating   timestamp      id
# 0             1     1.0  1425941529   as680
# 1             1     4.5  1425942435  ns2186
# 2             1     5.0  1425941523  hs2381
# 3             1     5.0  1425941546  ns3663
# 4             1     5.0  1425941556  as9500
# ...         ...     ...         ...     ...
# 1499995  124380     4.5  1196786159  ns5272
# 1499996  124380     2.5  1196786030  ns5492
# 1499997  124380     3.5  1196785679   hs305
# 1499998  124380     4.5  1196787089  ns7881
# 1499999  124380     1.5  1196785847   as883
#
# [11024289 rows x 4 columns]

# %%
agrupadosDfRatings=dfRatings[["id","rating","userId"]].groupby(by=['id']).mean()

# %%
res=pd.merge(b,agrupadosDfRatings, on="id",how="outer")
res.head(2)

# %%
res["rating_y"] = round(res["rating_y"].astype(dtype="float"),2)
res["userId"] = res["userId"].astype(dtype="int64")
res.head(2)

# %%
 

#cd
#.\venv\
#Set-ExecutionPolicy -ExecutionPolicy Remotesigned -Scope process
#.\Scripts\
#.\activate
#cd ..
#uvicorn main:app
#uvicorn main:app --reload
#http://localhost:8000
#http://localhost:8000/docs
